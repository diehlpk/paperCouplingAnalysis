# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,3,100)

# %%
plt.plot(x,np.sin(x*np.pi*2))

# %%
plt.plot(x,np.cos(x*np.pi*2+np.pi/2))

# %%
# Out:
# 6.123233995736766e-17
